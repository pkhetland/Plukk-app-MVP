# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

cs = 'postgres://qxtmarboumalkd:a70cd9ccf0b9b65bbb7d0da3bffe65c94f99c8b7c6d2a9cbfb2a24a15287074b@ec2-107-20-173-227.compute-1.amazonaws.com:5432/d7q3kba2rlkchv'

engine = create_engine(cs)

# %%
pd.read_sql_table('plukk_contacts', engine)
# Out:
#     index          name                     email
# 0       0        sdfasf                  asdfsadf
# 1       0        Petter  Petter.hetland@gmail.com
# 2       0          Test             Test@test.com
# 3       0   Petter_test  Petter.hetland@gmail.com
# 4       0
# 5       0
# 6       0
# 7       0
# 8       0
# 9       0
# 10      0  Øyvind S. H.        hetland@hetland.co
# 11      0          Test              Test@test.no
# 12      0          Test              Test@test.no
