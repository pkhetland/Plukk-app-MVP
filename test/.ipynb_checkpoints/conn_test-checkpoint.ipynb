# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

cs = 'postgres://qxtmarboumalkd:a70cd9ccf0b9b65bbb7d0da3bffe65c94f99c8b7c6d2a9cbfb2a24a15287074b@ec2-107-20-173-227.compute-1.amazonaws.com:5432/d7q3kba2rlkchv'

engine = create_engine(cs)

# %%
pd.read_sql_table('plukk_contacts', engine)
# Out:
#     index                 name                        email
# 0       0               Petter     Petter.hetland@gmail.com
# 1       0                 Test                 test@test.no
# 2       0               Nikhil      nikhil.luthra@bouvet.no
# 3       0               Petter     Petter.hetland@gmail.com
# 4       0                 Test                Test@test.com
# 5       0                Test3                 Test@test.no
# 6       0       Petter Hetland
# 7       0       Hilde Kvammen      hildekvammen@hotmail.com
# 8       0         Dag Sandvand        dagsandvand@gmail.com
# 9       0       Kristine Ausen       kristine.ausen@live.no
# 10      0  Simay Leblebicioglu      simaylebleb@hotmail.com
# 11      0      Stina Sehlstedt  stina.sehlstedt@hotmail.com
# 12      0            Ragnhild              ragode@gmail.com
# 13      0         Prodirkongen         prodirking@gmail.com
# 14      0         Prodirkongen         prodirking@gmail.com

# %%
with open('contacts.csv', 'w') as f:
    df = pd.read_sql_table('plukk_contacts', engine)
    writer = csv.writer(f)
    writer.write(df)
    f.close()
